# %% [markdown]
# ## Train model for accumulation area of all glaciers

# %%
# Import libraries
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GroupKFold
from matplotlib import pyplot as plt

from model_functions import select_variables
from model_functions import train_xgb_model

# %%
# Specify filepaths and filenames.
loc = 'local'

if loc == 'cryocloud':
    filepath = '/home/jovyan/ML_MB_Norway_data/'
elif loc == 'local':
    filepath = 'Data/'

filename = '2023-06-27_stake_mb_norway_cleaned_ids_latlon_wattributes_climate.csv'

# Load data.
data = pd.read_csv(filepath + filename)

# Add year column
data['year']=pd.to_datetime(data['dt_curr_year_max_date'].astype('string'), format="%d.%m.%Y %H:%M")
data['year'] = data.year.dt.year.astype('Int64')

# Remove cells with nan in balance_netto.
glacier_data_all = data[data['balance_netto'].notna()]
glacier_data_all.reset_index(drop=True, inplace=True)
glacier_data_all
# Out:
#                RGIID         GLIMSID  BREID  utm_zone  utm_east_approx  \
# 0     RGI60-08.01258  G021737E70130N     54        34         529400.0
# 1     RGI60-08.01258  G021737E70130N     54        34         529400.0
# 2     RGI60-08.01258  G021737E70130N     54        34         529400.0
# 3     RGI60-08.01258  G021737E70130N     54        34         529400.0
# 4     RGI60-08.01258  G021737E70130N     54        34         529400.0
# ...              ...             ...    ...       ...              ...
# 3834  RGI60-08.02969  G006362E59989N   3141        32         351800.0
# 3835  RGI60-08.02969  G006362E59989N   3141        32         351800.0
# 3836  RGI60-08.02969  G006362E59989N   3141        32         351800.0
# 3837  RGI60-08.02969  G006362E59989N   3141        32         351800.0
# 3838  RGI60-08.02969  G006362E59989N   3141        32         351800.0
#
#       utm_north_approx  altitude_approx location_description location_id  \
# 0            7780050.0            500.0  Nederst på bretunga         L10
# 1            7780050.0            500.0  Nederst på bretunga         L10
# 2            7780050.0            500.0  Nederst på bretunga         L10
# 3            7780050.0            500.0  Nederst på bretunga         L10
# 4            7780050.0            500.0  Nederst på bretunga         L10
# ...                ...              ...                  ...         ...
# 3834         6647500.0           1080.0  Nederst på bretunga         B15
# 3835         6647500.0           1080.0  Nederst på bretunga         B15
# 3836         6647500.0           1080.0  Nederst på bretunga         B15
# 3837         6647500.0           1080.0  Nederst på bretunga         B15
# 3838         6647500.0           1080.0  Nederst på bretunga         B15
#
#      stake_no  ...    tp_feb    tp_mar    tp_apr    tp_may    tp_jun  \
# 0       L1012  ...  0.005116  0.002688  0.002334  0.001159  0.003054
# 1       L1013  ...  0.001831  0.004597  0.005634  0.002244  0.003412
# 2       L1013  ...  0.004949  0.003286  0.003739  0.004709  0.005111
# 3       L1013  ...  0.002495  0.002263  0.001256  0.002129  0.003969
# 4       L1016  ...  0.003314  0.004417  0.002704  0.003991  0.001780
# ...       ...  ...       ...       ...       ...       ...       ...
# 3834    B1509  ...  0.011964  0.007288  0.003555  0.005019  0.004730
# 3835    B1509  ...  0.002572  0.000807  0.009360  0.006135  0.006760
# 3836    B1514  ...  0.008543  0.010311  0.006261  0.008175  0.005974
# 3837    B1514  ...  0.008916  0.003751  0.004573  0.004449  0.005235
# 3838    B1514  ...  0.007071  0.009703  0.007457  0.003567  0.008162
#
#         tp_jul    tp_aug    tp_sep altitude_climate  year
# 0     0.003977  0.004691  0.001449       341.227919  2013
# 1     0.000891  0.002129  0.004860       341.227919  2014
# 2     0.001253  0.002506  0.003256       341.227919  2015
# 3     0.003559  0.002119  0.002851       341.227919  2016
# 4     0.004257  0.005193  0.000710       341.227919  2017
# ...        ...       ...       ...              ...   ...
# 3834  0.007226  0.005739  0.011397       917.419759  2012
# 3835  0.005158  0.008218  0.005461       917.419759  2013
# 3836  0.006563  0.008015  0.003896       917.419759  2015
# 3837  0.008926  0.011151  0.009556       917.419759  2016
# 3838  0.007537  0.007390  0.006440       917.419759  2017
#
# [3839 rows x 302 columns]

# %%
# Select data where annual mass balance is less than zero.
glacier_data_acc = glacier_data_all[glacier_data_all['balance_netto'] >= 0]
glacier_data_acc.reset_index(drop=True, inplace=True)

# %%
plt.figure()
glacier_data_acc['balance_netto'].plot.hist(bins=100)
plt.title('Frequency of annual mass balance')
plt.ylabel('frequency')
plt.xlabel('annual mass balance')
plt.show()

plt.figure()
glacier_data_acc['year'].plot.hist(bins=50)
plt.title('Frequency of measurement year')
plt.ylabel('frequency')
plt.xlabel('year')
plt.show()

plt.figure()
glacier_data_acc['BREID'].plot.hist(bins=100)
plt.title('Frequency of individual glaciers')
plt.ylabel('frequency')
plt.xlabel('glacier id')
plt.show()

print('Number of glaciers:', glacier_data_acc['BREID'].unique().shape[0])
print('Number of years:', glacier_data_acc['year'].unique().shape[0])
print('Number of measurements: ', glacier_data_acc.shape[0])
print('Number of mb > 3: ', glacier_data_all[glacier_data_all['balance_netto'] >= 3].shape[0])
print('Glaciers with mb > 3 ', glacier_data_all[glacier_data_all['balance_netto'] >= 3]['BREID'].unique())
# Out:
# Number of glaciers: 31
# Number of years: 60
# Number of measurements:  1732
# Number of mb > 3:  54
# Glaciers with mb > 3  [ 941 1135 2078 2297 2320 3127 3133 3137 3141]

# %% [markdown]
# ## Leave glaciers out
# Ideally use leave years and glaciers out.
# Folds need to simultaneously block out glaciers and years, while maintaining a good balance of mass balance values.
#
# 1732/5 = 346.4 points in each fold with 5 folds
#
# 1732/4 = 433 points in each fold with 4 folds
#
# 1732/3 = 577.3 points in each fold with 3 folds
#
# Nigardsbreen (2297) has 601 points
#
# Ålfotbreen (2078) has 305 points

# %%
list(glacier_data_acc['BREID'].unique())
# Out:
# [54,
#  596,
#  675,
#  703,
#  941,
#  1092,
#  1094,
#  1135,
#  1144,
#  1280,
#  2078,
#  2085,
#  2148,
#  2297,
#  2320,
#  2474,
#  2478,
#  2514,
#  2597,
#  2768,
#  2769,
#  2772,
#  2968,
#  3126,
#  3127,
#  3128,
#  3129,
#  3133,
#  3137,
#  3138,
#  3141]

# %%
test_glaciers = [54, 703, 941, 1135, 1280, 2085, 2320, 2768, 2478, 2769, 3127, 3141]

df_test = glacier_data_acc[glacier_data_acc['BREID'].isin(test_glaciers)]
# 54 has 37 points
# 703 has 13 points
# 1280 has 25 points
# 2478 has 22 points
# 2769 has 10 points
# 3127 has 60 points

# test has 323 points in total

df_train = glacier_data_acc[~glacier_data_acc['BREID'].isin(test_glaciers)]

# %%
base_cols = ['altitude','aspect','slope','altitude_climate']
temp_cols = ['t2m_oct','t2m_nov','t2m_des','t2m_jan','t2m_feb','t2m_mar','t2m_apr','t2m_may','t2m_jun','t2m_jul','t2m_aug','t2m_sep']
prec_cols = ['tp_oct','tp_nov','tp_des','tp_jan','tp_feb','tp_mar','tp_apr','tp_may','tp_jun','tp_jul','tp_aug','tp_sep']
label_cols = ['balance_netto']

df_train_X = select_variables(df_train, base_cols, temp_cols, prec_cols)
df_train_y = select_variables(df_train, label_cols)
df_test_X = select_variables(df_test, base_cols, temp_cols, prec_cols)
df_test_y = select_variables(df_test, label_cols)

# 1409 for training (19 glaciers), 323 for testing (12 glaciers)
X_train, y_train = df_train_X.values, df_train_y.values
X_test, y_test = df_test_X.values, df_test_y.values

# %%
# Define parameter ranges.
param_ranges = {'max_depth': [2, 3, 4, 5, 6, 7, 8],
          'n_estimators': [50, 100, 150, 200, 250, 300, 350, 400], # number of trees (too many = overfitting, too few = underfitting)
          'learning_rate': [0.01, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3]}

# %%
gp = np.array(df_train['BREID'].values)

# %%
group_kf = GroupKFold(n_splits=5)
splits = list(group_kf.split(X_train, y_train, gp))

# Two of the splits have more test values. Split one where Nigardsbreen (approx 600 pts) 
# is test and split 2 where Ålfotbreen (approx 300 pts) is test. 
# With three folds, test sets will be more balanced in terms of number of points and glaciers.

# %%
best_model = train_xgb_model(X_train, y_train, splits, param_ranges, scorer='neg_mean_squared_error')
# Out:
# Fitting 5 folds for each of 392 candidates, totalling 1960 fits
# Cross validation score:  -0.523340801748396
# Grid search best hyperparameters:  {'learning_rate': 0.3, 'max_depth': 2, 'n_estimators': 50}
# Cross validation scores per fold:  [-0.91341507 -0.39631113 -0.42435115 -0.38463063 -0.49799601]
# Mean cross validation score:  -0.523340801748396
# Standard deviation:  0.1989855743927368

# %%
# Try with median absolute error instead of mean squared error (median squared error is not available). 

best_model_median = train_xgb_model(X_train, y_train, splits, param_ranges, scorer='neg_median_absolute_error')
# Out:
# Fitting 5 folds for each of 392 candidates, totalling 1960 fits
# Cross validation score:  -0.4123558373451234
# Grid search best hyperparameters:  {'learning_rate': 0.2, 'max_depth': 6, 'n_estimators': 50}
# Cross validation scores per fold:  [-0.88270173 -0.44530786 -0.44722094 -0.34856521 -0.60004344]
# Mean cross validation score:  -0.5447678382393935
# Standard deviation:  0.18716723313688713

# %% [markdown]
# ## Use fewer folds
#
# Using 3 folds instead of 5

# %%
group_kf = GroupKFold(n_splits=3)
splits = list(group_kf.split(X_train, y_train, gp))

# Train / test
# 808 / 601
# 601 / 1006 (Nigardsbreen)
# 1004 / 405

# %%
best_model = train_xgb_model(X_train, y_train, splits, param_ranges, scorer='neg_mean_squared_error')
# Out:
# Fitting 3 folds for each of 392 candidates, totalling 1176 fits
# Cross validation score:  -0.5945463496111664
# Grid search best hyperparameters:  {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 400}
# Cross validation scores per fold:  [-0.93449102 -0.4423009  -0.40684712]
# Mean cross validation score:  -0.5945463496111664
# Standard deviation:  0.24081255183597325

# %% [markdown]
# ## Shuffle glaciers first - NOT WORKING, GIVES THE SAME FOLDS AS WITHOUT SHUFFLE, NEED TO SHUFFLE DATASET FIRST.
#
#
# In the above, glaciers are not shuffled prior to Group-K-fold split, such that they are to a large degree gouped by region. This likely leads to some folds with glaciers that have large mass turnover and some folds with glaciers that have low mass turnover, and thus extrapolation issues for large values. Try shuffle glaciers first and then Group-K-fold split.

# %%
df_train
# Out:
#                RGIID         GLIMSID  BREID  utm_zone  utm_east_approx  \
# 37    RGI60-08.02436  G017852E68340N    596        33         617900.0
# 38    RGI60-08.02436  G017852E68340N    596        33         617700.0
# 39    RGI60-08.02436  G017852E68340N    596        33         617500.0
# 40    RGI60-08.02436  G017852E68340N    596        33         617500.0
# 41    RGI60-08.02436  G017852E68340N    596        33         617700.0
# ...              ...             ...    ...       ...              ...
# 1693  RGI60-08.02918  G006320E59995N   3137        32         349450.0
# 1694  RGI60-08.02918  G006320E59995N   3137        32         349450.0
# 1695  RGI60-08.02920  G006269E59989N   3138        32         347450.0
# 1696  RGI60-08.02920  G006269E59989N   3138        32         348450.0
# 1697  RGI60-08.02920  G006269E59989N   3138        32         349800.0
#
#       utm_north_approx  altitude_approx location_description location_id  \
# 37           7583700.0            980.0                  NaN        BLÅ5
# 38           7583600.0           1000.0                  NaN        BLÅ6
# 39           7583500.0           1025.0                  NaN        BLÅ7
# 40           7583500.0           1025.0                  NaN        BLÅ7
# 41           7583100.0           1040.0                  NaN       BLÅ71
# ...                ...              ...                  ...         ...
# 1693         6648500.0           1155.0                  NaN         S20
# 1694         6648500.0           1155.0                  NaN         S20
# 1695         6652150.0           1400.0                  NaN         M41
# 1696         6654150.0           1515.0                  NaN         M61
# 1697         6656300.0           1615.0                  NaN         M71
#
#      stake_no  ...    tp_feb    tp_mar    tp_apr    tp_may    tp_jun  \
# 37       BLÅ5  ...  0.005572  0.003607  0.002414  0.002636  0.002415
# 38       BLÅ6  ...  0.005572  0.003607  0.002414  0.002636  0.002415
# 39       BLÅ7  ...  0.002994  0.002428  0.001993  0.002906  0.003402
# 40       BLÅ7  ...  0.004887  0.004874  0.004694  0.001514  0.004824
# 41      BLÅ71  ...  0.004887  0.004874  0.004694  0.001514  0.004824
# ...       ...  ...       ...       ...       ...       ...       ...
# 1693    S2007  ...  0.011820  0.007538  0.003579  0.005019  0.004988
# 1694    S2013  ...  0.008474  0.010181  0.006399  0.008094  0.006076
# 1695    M4116  ...  0.006958  0.009505  0.007355  0.003641  0.008233
# 1696    M6116  ...  0.006958  0.009505  0.007355  0.003641  0.008233
# 1697    M7116  ...  0.006958  0.009505  0.007355  0.003641  0.008233
#
#         tp_jul    tp_aug    tp_sep altitude_climate  year
# 37    0.003819  0.002669  0.002678      1001.181943  1965
# 38    0.003819  0.002669  0.002678      1001.181943  1965
# 39    0.003066  0.004062  0.004951      1001.181943  1964
# 40    0.003683  0.004470  0.001097      1001.181943  1968
# 41    0.003683  0.004470  0.001097      1001.181943  1968
# ...        ...       ...       ...              ...   ...
# 1693  0.007411  0.005817  0.011165      1046.032689  2012
# 1694  0.006683  0.008148  0.003977      1046.032689  2015
# 1695  0.007808  0.007504  0.006324      1046.032689  2017
# 1696  0.007808  0.007504  0.006324      1046.032689  2017
# 1697  0.007808  0.007504  0.006324      1046.032689  2017
#
# [1409 rows x 302 columns]

# %%
# Shuffle df_train, get X and y values
df_train_s = df_train.sample(frac=1, random_state=5)
df_train_s.reset_index(drop=True, inplace=True)
df_train_s
# Out:
#                RGIID         GLIMSID  BREID  utm_zone  utm_east_approx  \
# 0     RGI60-08.01126  G007099E61715N   2297        32         398340.0
# 1     RGI60-08.01779  G007405E60537N   2968        32         414000.0
# 2     RGI60-08.01126  G007099E61715N   2297        32         398340.0
# 3     RGI60-08.01126  G007099E61715N   2297        32         403100.0
# 4     RGI60-08.02666  G005644E61747N   2078        32         322300.0
# ...              ...             ...    ...       ...              ...
# 1404  RGI60-08.02458  G017917E68217N    675        33         619850.0
# 1405  RGI60-08.01126  G007099E61715N   2297        32         401030.0
# 1406  RGI60-08.01126  G007099E61715N   2297        32         400000.0
# 1407  RGI60-08.01657  G013853E66657N   1094        33         449400.0
# 1408  RGI60-08.01126  G007099E61715N   2297        32         396170.0
#
#       utm_north_approx  altitude_approx  \
# 0            6841270.0           1790.0
# 1            6712700.0           1822.0
# 2            6841270.0           1790.0
# 3            6846900.0           1800.0
# 4            6851900.0           1180.0
# ...                ...              ...
# 1404         7570850.0           1515.0
# 1405         6846640.0           1760.0
# 1406         6844900.0           1665.0
# 1407         7395900.0           1050.0
# 1408         6839900.0           1960.0
#
#                                    location_description location_id stake_no  \
# 0                                                   NaN         N56    N5674
# 1                               Nedafor høgste brekulen          H2       H2
# 2                                                   NaN         N56    N5693
# 3                                         Lengst i nord         N88    N8866
# 4                                          Nær garasjen        AA45   AA4500
# ...                                                 ...         ...      ...
# 1404                                                NaN       STO22  STO2264
# 1405                    I bakken øst for Kjenndalskruna         N96    N9609
# 1406  På flata nordøst for Kjenndalskruna, like ved ...         N80    N8064
# 1407  På stor flate der det ofte er meir snø enn på ...         E38    E3770
# 1408                                   Høgste Breakulen         N57    N5717
#
#       ...    tp_feb    tp_mar    tp_apr    tp_may    tp_jun    tp_jul  \
# 0     ...  0.002598  0.001941  0.003448  0.003203  0.003269  0.003300
# 1     ...  0.002459  0.002348  0.002958  0.002812  0.002889  0.004992
# 2     ...  0.011406  0.012253  0.006661  0.003143  0.002514  0.004223
# 3     ...  0.001838  0.005701  0.001557  0.003958  0.002868  0.004766
# 4     ...  0.016382  0.008816  0.003778  0.004761  0.008890  0.001088
# ...   ...       ...       ...       ...       ...       ...       ...
# 1404  ...  0.003014  0.002444  0.002118  0.002995  0.003608  0.003114
# 1405  ...  0.003896  0.004684  0.002291  0.005193  0.003733  0.005794
# 1406  ...  0.005130  0.000585  0.004163  0.003896  0.008467  0.007440
# 1407  ...  0.003324  0.007082  0.003799  0.001050  0.002815  0.006945
# 1408  ...  0.004144  0.006496  0.006562  0.002475  0.006017  0.007002
#
#         tp_aug    tp_sep altitude_climate  year
# 0     0.002306  0.012354      1382.210502  1975
# 1     0.002787  0.004506      1231.375486  2005
# 2     0.004101  0.008881      1382.210502  1997
# 3     0.003515  0.009376      1322.716089  1966
# 4     0.005618  0.007280       653.949191  2000
# ...        ...       ...              ...   ...
# 1404  0.004406  0.005214      1025.245691  1964
# 1405  0.007957  0.010030      1382.210502  2009
# 1406  0.005040  0.007061      1382.210502  1964
# 1407  0.006944  0.009133       808.263013  1972
# 1408  0.006264  0.003482      1362.652086  2017
#
# [1409 rows x 302 columns]

# %%
df_train_X_s = select_variables(df_train_s, base_cols, temp_cols, prec_cols)
df_train_y_s = select_variables(df_train_s, label_cols)

X_train_s, y_train_s = df_train_X_s.values, df_train_y_s.values

gp_s = np.array(df_train_s['BREID'].values)

# %%
# Shuffle groups
#unique_values, indexes, inverse = np.unique(gp, return_inverse=True, return_index=True)
#gp_new = indexes[inverse]
#gp_new
print(gp)
print(gp_s)
# Out:
# [ 596  596  596 ... 3138 3138 3138]
# [2297 2968 2297 ... 2297 1094 2297]

# %%
# With five folds
group_kf = GroupKFold(n_splits=5)
splits_s = list(group_kf.split(X_train_s, y_train_s, gp_s))

# %%
#splits[0][1]

# %%
#splits_s[0][1]

# %%
len(splits[2][1])

# 808 /601
# 1104 / 305
# 1241 / 168
# 1241 / 168
# 1242 / 167
# Out:
# 168

# %% [markdown]
# Scores without shuffling:
#
# Cross validation scores per fold:  [-0.88270173 -0.44530786 -0.44722094 -0.34856521 -0.60004344]
#
# Mean cross validation score:  -0.5447678382393935
#
# Standard deviation:  0.18716723313688713

# %%
best_model = train_xgb_model(X_train_s, y_train_s, splits_s, param_ranges, scorer='neg_mean_squared_error')
# Out:
# Fitting 5 folds for each of 392 candidates, totalling 1960 fits
# Cross validation score:  -0.523340801748396
# Grid search best hyperparameters:  {'learning_rate': 0.3, 'max_depth': 2, 'n_estimators': 50}
# Cross validation scores per fold:  [-0.91341507 -0.39631113 -0.42435115 -0.38463063 -0.49799601]
# Mean cross validation score:  -0.523340801748396
# Standard deviation:  0.1989855743927368

# %% [markdown]
# Slightly better performance with shuffling than without.

# %%
# Using R2 scorer instead

best_model = train_xgb_model(X_train_s, y_train_s, splits_s, param_ranges, scorer='r2')
# Out:
# Fitting 5 folds for each of 392 candidates, totalling 1960 fits
# Cross validation score:  0.13566149267203703
# Grid search best hyperparameters:  {'learning_rate': 0.3, 'max_depth': 2, 'n_estimators': 50}
# Cross validation scores per fold:  [-0.91341507 -0.39631113 -0.42435115 -0.38463063 -0.49799601]
# Mean cross validation score:  -0.523340801748396
# Standard deviation:  0.1989855743927368

# %%
# With three folds
group_kf = GroupKFold(n_splits=3)
splits_s = list(group_kf.split(X_train_s, y_train_s, gp_s))

# %%
best_model = train_xgb_model(X_train_s, y_train_s, splits_s, param_ranges, scorer='neg_mean_squared_error')
# Out:
# Fitting 3 folds for each of 392 candidates, totalling 1176 fits
# Cross validation score:  -0.5945463496111664
# Grid search best hyperparameters:  {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 400}
# Cross validation scores per fold:  [-0.93449102 -0.4423009  -0.40684712]
# Mean cross validation score:  -0.5945463496111664
# Standard deviation:  0.24081255183597325

# %% [markdown]
# ## Upsample glaciers
