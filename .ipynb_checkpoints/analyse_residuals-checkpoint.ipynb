# %% [markdown]
# # Analysis/plots of model residuals

# %% [markdown]
# ## Check for spatial correlations in residuals of random k-fold models

# %%
# Import libraries
import joblib
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.model_selection import GroupKFold
from matplotlib import pyplot as plt
import xgboost as xgb
import gstools as gs
from matplotlib import pyplot as plt
from scipy.stats import gaussian_kde

from model_functions import select_variables
from model_functions import train_xgb_model
from model_functions import get_model_residuals
from plotting_functions import plot_gsearch_results
from plotting_functions import plot_prediction_per_fold
from plotting_functions import plot_prediction

# %%
# Specify filepaths and filenames.
loc = 'local'

if loc == 'cryocloud':
    filepath = '/home/jovyan/ML_MB_Norway_data/'
elif loc == 'local':
    filepath = 'Data/'

filename = '2023-08-28_stake_mb_norway_cleaned_ids_latlon_wattributes_climate.csv'

# Load data.
data = pd.read_csv(filepath + filename)

# Add year column
data['year']=pd.to_datetime(data['dt_curr_year_max_date'].astype('string'), format="%d.%m.%Y %H:%M")
data['year'] = data.year.dt.year.astype('Int64')

# Remove cells with nan in balance_netto.
glacier_data_all = data[data['balance_netto'].notna()]
glacier_data_all.reset_index(drop=True, inplace=True)

# Manually select test glaciers
test_glaciers = [54, 703, 941, 1135, 1280, 2085, 2320, 2768, 2478, 2769, 3127, 3141]
#test_glaciers = [54, 703, 941, 1135, 1280, 2320, 2478, 2769, 3127, 3141]

df_test = glacier_data_all[glacier_data_all['BREID'].isin(test_glaciers)]
# 54 has 37 points
# 703 has 13 points
# 1280 has 25 points
# 2478 has 22 points
# 2769 has 10 points
# 3127 has 60 points
# test has 323 points in total

df_train = glacier_data_all[~glacier_data_all['BREID'].isin(test_glaciers)]

# Run with different random seeds
rand_seed = 25
# Out:
# C:\Users\kasj\AppData\Local\Temp\ipykernel_18672\1989724952.py:12: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(filepath + filename)

# %%
# Select features
base_cols = ['altitude','aspect','slope','altitude_climate','lat','lon']
temp_cols = ['t2m_oct','t2m_nov','t2m_dec','t2m_jan','t2m_feb','t2m_mar','t2m_apr','t2m_may','t2m_jun','t2m_jul','t2m_aug','t2m_sep']
prec_cols = ['tp_oct','tp_nov','tp_dec','tp_jan','tp_feb','tp_mar','tp_apr','tp_may','tp_jun','tp_jul','tp_aug','tp_sep']
label_cols = ['balance_netto']

# Select features for training
df_train_X = select_variables(df_train, base_cols, temp_cols, prec_cols)

# Select labels for training
df_train_y = select_variables(df_train, label_cols)

X_train, y_train = df_train_X.values, df_train_y.values

# Use five folds
kf = KFold(n_splits=5, shuffle=True, random_state=rand_seed)
splits = list(kf.split(X_train, y_train))

# %%
#joblib.dump(cv_grid, 'Models/Random_5fold/cv_random_5fold_temp_prec_seed25.pkl')
cv_grid = joblib.load('Models/Random_5fold/cv_random_5fold_temp_prec_seed25.pkl')

# %%
fitted_model = xgb.XGBRegressor(**cv_grid.best_params_)

# %%
residuals = get_model_residuals(X_train, y_train, fitted_model, splits)

# %%
residuals.shape
# Out:
# (2809,)

# %%
print(X_train[0][4])
print(X_train[0][5])
# Out:
# 68.34460666077922
# 17.86015112957877

# %% [markdown]
# ## Estimate variogram of residuals

# %%
lon_list = []
lat_list = []
alt_list = []

for train_index, val_index in splits:
    # Loops over n_splits iterations and gets train and test splits in each fold
    X_train_ign, X_val = X_train[train_index], X_train[val_index]
    #X_train_ign, X_val_alt = X_train[train_index], X_train[val_index]
    #X_train_ign, X_val_lon = X_train[train_index], X_train[val_index]

    X_lat = X_val[:,4]
    X_lon = X_val[:,5]
    X_alt = X_val[:,0]
    
    lat_list.extend(X_lat)
    lon_list.extend(X_lon)
    alt_list.extend(X_alt)
        
# Arrays of predictions and observations for each fold
lat_all = np.hstack([*lat_list])
lon_all = np.hstack([*lon_list])
alt_all = np.hstack([*alt_list])

# %%
alt_all
# Out:
# array([ 996. ,  988. ,  981. , ..., 1154. , 1145. , 1513.3])

# %%
#x = data_job['lon'].values
#y = data_job['lat'].values
#mb = data_job['balance_netto'].values
coords = np.stack((lon_all,lat_all), axis=1)

# Use only data that is not nan
#coords=coords[~np.isnan(mb)]
#mb_clean=mb[~np.isnan(mb)]

# %%
# estimate the variogram of the field
bin_center, gamma = gs.vario_estimate((lon_all, lat_all), residuals, latlon=True, geo_scale=gs.KM_SCALE)

print('bin_center: ', bin_center)
print('gamma: ', gamma)
print("estimated bin number:", len(bin_center))
print("maximal bin distance:", max(bin_center))
# Out:
# bin_center:  [ 11.46481707  34.39445122  57.32408537  80.25371952 103.18335367
#  126.11298782 149.04262197 171.97225612 194.90189027 217.83152441
#  240.76115856 263.69079271 286.62042686 309.55006101 332.47969516
#  355.40932931 378.33896346 401.26859761 424.19823175 447.1278659
#  470.05750005 492.9871342  515.91676835 538.8464025 ]
# gamma:  [0.38179609 0.33532766 0.37151586 0.48654157 0.46982091 0.40008305
#  0.32575189 0.40809838 0.39684302 0.34315392 0.34864048 0.41644276
#  0.40233528 0.40563555 0.25891225 0.         0.         0.
#  0.         0.53833652 0.17281399 0.56324893 0.24386688 0.        ]
# estimated bin number: 24
# maximal bin distance: 538.8464024985662

# %%
models = {
    "Gaussian": gs.Gaussian,
    "Exponential": gs.Exponential,
    "Matern": gs.Matern,
    "Stable": gs.Stable,
    "Rational": gs.Rational,
    "Circular": gs.Circular,
    "Spherical": gs.Spherical,
    "SuperSpherical": gs.SuperSpherical,
    "JBessel": gs.JBessel,
}
scores = {}

# %%
# plot the estimated variogram
plt.scatter(bin_center, gamma, color="k", label="data")
ax = plt.gca()

# fit all models to the estimated variogram
for model in models:
    fit_model = models[model](dim=2)
    para, pcov, r2 = fit_model.fit_variogram(bin_center, gamma, return_r2=True)
    fit_model.plot(x_max=max(bin_center), ax=ax)
    scores[model] = r2
print(fit_model)
# Out:
# C:\Program Files\Anaconda3\envs\ML_MB_Norway_env\lib\site-packages\gstools\covmodel\plot.py:121: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# JBessel(dim=2, var=2.17e-16, len_scale=3.03e+03, nugget=0.305, nu=50.0)

# %%
plt.scatter(lat_all, residuals)
plt.plot(lat_all, np.zeros(lat_all.shape), color='k')

# %%
plt.scatter(lon_all, residuals)
plt.plot(lon_all, np.zeros(lon_all.shape), color='k')

# %%
plt.hist(residuals, bins=50);

# %%
plt.scatter(alt_all, residuals)
plt.plot(alt_all, np.zeros(lon_all.shape), color='k')

# %% [markdown]
# ## Analyse residuals block-glacier model with annual, summer, winter

# %%
# Specify filepaths and filenames.
loc = 'local'

if loc == 'cryocloud':
    filepath = '/home/jovyan/ML_MB_Norway_data/'
elif loc == 'local':
    filepath = 'Data/'

filename = '2023-08-28_stake_mb_norway_cleaned_ids_latlon_wattributes_climate.csv'

# Load data.
data = pd.read_csv(filepath + filename)

# Add year column
data['year']=pd.to_datetime(data['dt_curr_year_max_date'].astype('string'), format="%d.%m.%Y %H:%M")
data['year'] = data.year.dt.year.astype('Int64')
data['id'] = np.arange(0,data.index.shape[0])
data['ann+seas'] = np.where(((data['balance_winter'].notna()) & (data['balance_summer'].notna()) & (data['balance_netto'].notna())), True, False)
#data['ann+seas'] = ((data['balance_winter'].notna()) & (data['balance_summer'].notna()) & (data['balance_netto'].notna()))

# Remove cells with nan in balance_netto.
glacier_data_annual = data[data['balance_netto'].notna()]
glacier_data_annual.reset_index(drop=True, inplace=True)

glacier_data_winter = data[data['balance_winter'].notna()]
glacier_data_winter.reset_index(drop=True, inplace=True)

glacier_data_summer = data[data['balance_summer'].notna()]
glacier_data_summer.reset_index(drop=True, inplace=True)
# Out:
# C:\Users\kasj\AppData\Local\Temp\ipykernel_20484\110895985.py:12: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(filepath + filename)

# %%
#data[data['ann+seas']==True].shape
#data.shape
#

#data[data['balance_winter'].notna()].shape
# Out:
# (3710, 304)

# %%
# Manually select test glaciers
test_glaciers = [54, 703, 941, 1135, 1280, 2320, 2478, 2769, 3127, 3141]

df_test_annual = glacier_data_annual[glacier_data_annual['BREID'].isin(test_glaciers)]
df_test_winter = glacier_data_winter[glacier_data_winter['BREID'].isin(test_glaciers)]
df_test_summer = glacier_data_summer[glacier_data_summer['BREID'].isin(test_glaciers)]
# 54 has 189 points
# 703 has 30 points
# 941 has 70 points
# 1280 has 71 points
# 2320 has 83 points
# 2478 has 89 points
# 2769 has 121 points
# 3127 has 145 points
# 3141 has 72 points
# Test dataset has 926 points in total, approximately 24% of the data
# Train dataset has 2984 points, approximately 76% of the data

df_train_annual = glacier_data_annual[~glacier_data_annual['BREID'].isin(test_glaciers)]
df_train_winter = glacier_data_winter[~glacier_data_winter['BREID'].isin(test_glaciers)]
df_train_summer = glacier_data_summer[~glacier_data_summer['BREID'].isin(test_glaciers)]

# %%
# Add number of months to each dataframe
df_train_annual['n_months']=12
df_train_winter['n_months']=8
df_train_summer['n_months']=6

# Create boolean column with True if both winter, summer and annual mass balance observations exist for the given point, else False.
#df_train_annual['ann+seas'] = np.where(((df_train_annual['balance_winter'].notna()) & (df_train_annual['balance_summer'].notna())), True, False)
#df_train_winter['ann+seas'] = np.where(((df_train_winter['balance_netto'].notna()) & (df_train_winter['balance_summer'].notna())), True, False)
#df_train_summer['ann+seas'] = np.where(((df_train_summer['balance_winter'].notna()) & (df_train_summer['balance_netto'].notna())), True, False)

#df_train_annual['id'] = np.where((df_train_annual['ann+seas']==True), np.arange(0,2850), np.nan)
# Out:
# C:\Users\kasj\AppData\Local\Temp\ipykernel_20484\4231912390.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train_annual['n_months']=12
# C:\Users\kasj\AppData\Local\Temp\ipykernel_20484\4231912390.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train_winter['n_months']=8
# C:\Users\kasj\AppData\Local\Temp\ipykernel_20484\4231912390.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train_summer['n_months']=6

# %%
#(df_train_summer['ann+seas']==True).shape
# Out:
# (3039,)

# %%
# Select columns to drop
cols = ['RGIID','GLIMSID','utm_zone','utm_east_approx','utm_north_approx','altitude_approx',
        'location_description','location_id','stake_no','utm_east','utm_north','dt_prev_year_min_date','dt_curr_year_max_date',
        'dt_curr_year_min_date','stake_remark','flag_correction','approx_loc','approx_altitude',
        'diff_north','diff_east','diff_altitude','diff_netto','lat_approx','lon_approx',
        'topo','dis_from_border','year', 'lat','lon', 'ann+seas', 'id']

snow_depth_m = ['sde_oct','sde_nov','sde_dec','sde_jan','sde_feb','sde_mar','sde_apr','sde_may','sde_jun','sde_jul','sde_aug','sde_sep']
snow_density = ['rsn_oct','rsn_nov','rsn_dec','rsn_jan','rsn_feb','rsn_mar','rsn_apr','rsn_may','rsn_jun','rsn_jul','rsn_aug','rsn_sep']
evaporation = ['es_oct','es_nov','es_dec','es_jan','es_feb','es_mar','es_apr','es_may','es_jun','es_jul','es_aug','es_sep']
snow_cover = ['snowc_oct','snowc_nov','snowc_dec','snowc_jan','snowc_feb','snowc_mar','snowc_apr','snowc_may','snowc_jun','snowc_jul','snowc_aug','snowc_sep']
snow_depth_we = ['sd_oct','sd_nov','sd_dec','sd_jan','sd_feb','sd_mar','sd_apr','sd_may','sd_jun','sd_jul','sd_aug','sd_sep']
snow_temp = ['tsn_oct','tsn_nov','tsn_dec','tsn_jan','tsn_feb','tsn_mar','tsn_apr','tsn_may','tsn_jun','tsn_jul','tsn_aug','tsn_sep']
snow_melt = ['smlt_oct','smlt_nov','smlt_dec','smlt_jan','smlt_feb','smlt_mar','smlt_apr','smlt_may','smlt_jun','smlt_jul','smlt_aug','smlt_sep']
snowfall = ['sf_oct','sf_nov','sf_dec','sf_jan','sf_feb','sf_mar','sf_apr','sf_may','sf_jun','sf_jul','sf_aug','sf_sep']
snow_albedo = ['asn_oct','asn_nov','asn_dec','asn_jan','asn_feb','asn_mar','asn_apr','asn_may','asn_jun','asn_jul','asn_aug','asn_sep']
dewpt_temp = ['d2m_oct','d2m_nov','d2m_dec','d2m_jan','d2m_feb','d2m_mar','d2m_apr','d2m_may','d2m_jun','d2m_jul','d2m_aug','d2m_sep']
surface_pressure = ['sp_oct','sp_nov','sp_dec','sp_jan','sp_feb','sp_mar','sp_apr','sp_may','sp_jun','sp_jul','sp_aug','sp_sep']
sol_rad_down = ['ssrd_oct','ssrd_nov','ssrd_dec','ssrd_jan','ssrd_feb','ssrd_mar','ssrd_apr','ssrd_may','ssrd_jun','ssrd_jul','ssrd_aug','ssrd_sep']
sol_therm_down = ['strd_oct','strd_nov','strd_dec','strd_jan','strd_feb','strd_mar','strd_apr','strd_may','strd_jun','strd_jul','strd_aug','strd_sep']

drop_cols = [y for x in [cols, snow_depth_m, snow_density, evaporation, snow_cover, snow_depth_we, snow_temp, snow_melt, snowfall, snow_albedo, dewpt_temp, surface_pressure, sol_rad_down, sol_therm_down] for y in x]

# Select features for training
df_train_annual_clean = df_train_annual.drop(drop_cols, axis=1)
df_train_winter_clean = df_train_winter.drop(drop_cols, axis=1)
df_train_summer_clean = df_train_summer.drop(drop_cols, axis=1)
df_train_annual_clean = df_train_annual_clean.drop(['balance_winter','balance_summer'], axis=1)
df_train_winter_clean = df_train_winter_clean.drop(['balance_netto', 'balance_summer'], axis=1)
df_train_summer_clean = df_train_summer_clean.drop(['balance_netto', 'balance_winter'], axis=1)

# Rename target columns to same name
df_train_annual_clean.rename(columns={'balance_netto' : 'balance'}, inplace=True)
df_train_winter_clean.rename(columns={'balance_winter' : 'balance'}, inplace=True)
df_train_summer_clean.rename(columns={'balance_summer' : 'balance'}, inplace=True)

# df_train_X_... now contains columns of all chosen features and column with annual, winter or summer balance

# %%
# For summer balance, replace column values in accumulation months with NaN (oct, nov, dec, jan, feb, mar, apr, may)
# For winter balance, replace column values in ablation months with NaN (may, jun, jul, aug, sep, oct)

var = ['u10', 'v10', 't2m', 'fal', 'sshf', 'slhf', 'ssr', 'str', 'tp']
mon_summer = ['may', 'jun', 'jul', 'aug', 'sep', 'oct']
mon_winter = ['oct', 'nov', 'dec', 'jan', 'feb', 'mar', 'apr', 'may']

for name in var:
    for mon in mon_summer:
        df_train_winter_clean[name+'_'+mon]= np.nan
for name in var:   
    for mon in mon_winter:
        df_train_summer_clean[name+'_'+mon]= np.nan

# %%
# Combine the three dataframes
df_train_all = pd.concat([df_train_annual_clean, df_train_summer_clean, df_train_winter_clean])
df_train_all.reset_index(drop=True, inplace=True)
df_train_a_w_s_all = pd.concat([df_train_annual, df_train_summer, df_train_winter])
df_train_a_w_s_all.reset_index(drop=True, inplace=True)

# %%
# Shuffle df_train, get X and y values
df_train_s = df_train_all.sample(frac=1, random_state=5)
idx_train_s = df_train_s.index
df_train_s.reset_index(drop=True, inplace=True)

# Shuffle dataframe to be used in plots according to shuffled index of training dataset
df_train_a_w_s_all_s = df_train_a_w_s_all.reindex(idx_train_s)
df_train_a_w_s_all_s.reset_index(drop=True, inplace=True)

# %%
# Select features for training
df_train_X_s = df_train_s.drop(['balance','BREID'], axis=1)

# Select labels for training
df_train_y_s = df_train_s[['balance']]

X_train_s, y_train_s = df_train_X_s.values, df_train_y_s.values

# %%
# Get glacier IDs from training dataset (in the order of which they appear in training dataset).
# gp_s is an array with shape equal to the shape of X_train_s and y_train_s.
gp_s = np.array(df_train_s['BREID'].values)

# Use five folds
group_kf = GroupKFold(n_splits=5)

# Split into folds according to group by glacier ID.
# For each unique glacier ID, indices in gp_s indicate which rows in X_train_s and y_train_s belong to the glacier.
splits_s = list(group_kf.split(X_train_s, y_train_s, gp_s))

# %%
# Save cv-object
#joblib.dump(cv_grid, 'Models/Block_glacier_5fold_ann+seas/cv_block_glacier_5fold_minimal_climate_700_trees.pkl')
cv_grid = joblib.load('Models/Block_glacier_5fold_ann+seas/cv_block_glacier_5fold_minimal_climate_700_trees.pkl')

# %%
fitted_model = xgb.XGBRegressor(**cv_grid.best_params_)

# %%
residuals = get_model_residuals(X_train_s, y_train_s, fitted_model, splits_s)

# %%
residuals.shape
# Out:
# (8912,)

# %%
def plot_residuals(X_train_s, y_train_s, fitted_model, splits_s, type='annual', plot=False):

    y_pred_list = []
    y_test_list = []
    i=0

    if type=='annual':
        months=12
    elif type=='winter':
        months=8
    elif type=='summer':
        months=6
    else:
        months=12

    for train_index, test_index in splits_s:
        # Loops over n_splits iterations and gets train and test splits in each fold
        X_train, X_test = X_train_s[train_index], X_train_s[test_index]
        y_train, y_test = y_train_s[train_index], y_train_s[test_index]
        #y_resid = residuals[test_index]
        fitted_model.fit(X_train, y_train)
        y_pred = fitted_model.predict(X_test)

        indices = np.argwhere((X_test == months))[:,0]
        y_test_crop = y_test[indices]
        y_pred_crop = y_pred[indices]

        y_test_list.extend(y_test_crop)
        y_pred_list.extend(y_pred_crop)
        
        i=i+1

    # Arrays of predictions and observations for each fold
    y_test_all = np.hstack([*y_test_list])
    y_pred_all = np.hstack([*y_pred_list])
    residuals_cropped = y_test_all - y_pred_all

    fontsize_labels=12

    mae = round(abs(residuals_cropped).mean(),3)

    if plot==True:
    
        # Residuals vs. predicted mass balance as scatter plot
        fig1, ax = plt.subplots(1,1, figsize=(6,6))
        ax.scatter(y_pred_all, abs(residuals_cropped), color='red', alpha=0.2)

        def fit(ax, x,y, sort=True):
            z = np.polyfit(x, y, 5)
            fit = np.poly1d(z)
            if sort:
                x = np.sort(x)
            ax.plot(x, fit(x), color="darkred", alpha=1, lw=3  )  
            #ax.legend()

        fit(ax, y_pred_all, abs(residuals_cropped), sort=True) 

        ax.set_xlabel('Predicted ' + type + ' point mass balance (m w.e.)', fontsize=fontsize_labels)
        ax.set_ylabel('Absolute error (m w.e.)', fontsize=fontsize_labels)
        ax.grid(visible=True, which='both')

        # Histogram of residuals
        fig2 = plt.figure(figsize=(6,6))
        plt.hist(residuals_cropped, bins=51, edgecolor="k", color="#ffb07c"); # bins=50 with all annual mb data
        plt.axvline(0.0, ls='--', c='red')
        plt.grid()
        plt.ylabel('Count', fontsize = fontsize_labels)
        plt.xlabel('Misfit ' + type + ' (m w.e.)', fontsize=fontsize_labels)
        #plt.xlim([-2,2])

        # Residuals vs. predicted mass balance as density plot
        xy = np.vstack([y_pred_all, residuals_cropped])
        z = gaussian_kde(xy)(xy)
        idx = z.argsort()
        # Sort the points by density, so that the densest points are plotted last
        y_plt, ann_plt, z = y_pred_all[idx], residuals_cropped[idx], z[idx]

        fig3 = plt.figure(figsize=(6,6))
        plt.ylabel('Absolute error (m.w.e)', fontsize=fontsize_labels)
        plt.xlabel('Predicted point '+ type + ' mass balance (m w.e.)', fontsize=fontsize_labels)
        sc = plt.scatter(y_plt, abs(ann_plt), c=z, s=15)
        plt.clim(0,0.2)
        textstr = 'MAE (m w.e.): '+ str(mae)
        #plt.text(plt.xlim()[1]*0.1, 7, textstr,  
        #     fontsize = 16, color = 'k')

        def fit(x,y, sort=True):
            z = np.polyfit(x, y, 5)
            fit = np.poly1d(z)
            if sort:
                x = np.sort(x)
            plt.plot(x, fit(x), color="k", alpha=1, lw=3  )  
        
        fit(y_plt, abs(ann_plt), sort=True) 
    
        plt.tick_params(labelsize=10)
        #plt.colorbar(sc) 
        plt.axhline(0.0, ls='-.', c='k')
        plt.gca().set_box_aspect(1)
        plt.grid(alpha=0.5)

        plt.show()

    return y_test_all, y_pred_all, residuals_cropped

# %%
y_test, y_pred, residuals = plot_residuals(X_train_s, y_train_s, fitted_model, splits_s, type='winter', plot=True)

# %%
y_test_winter, y_pred_winter, residuals_winter = plot_residuals(X_train_s, y_train_s, fitted_model, splits_s, type='winter', plot=False)
y_test_summer, y_pred_summer, residuals_summer = plot_residuals(X_train_s, y_train_s, fitted_model, splits_s, type='summer', plot=False)
y_test_annual, y_test_summer, residuals_annual = plot_residuals(X_train_s, y_train_s, fitted_model, splits_s, type='annual', plot=False)

# %%
# Plot residuals vs elevation and location

type = 'annual'

lon_list = []
lat_list = []
alt_list = []
breid_list = []
y_pred_list = []
y_test_list = []
i=0

if type=='annual':
    months=12
elif type=='winter':
    months=8
elif type=='summer':
    months=6
else:
    months=12

for train_index, test_index in splits_s:
    # Loops over n_splits iterations and gets train and test splits in each fold
    #X_train_ign, X_test = X_train_s[train_index], X_train_s[test_index]
    X_train, X_test = X_train_s[train_index], X_train_s[test_index]
    y_train, y_test = y_train_s[train_index], y_train_s[test_index]
    df_features_test = df_train_a_w_s_all_s.iloc[test_index]

    fitted_model.fit(X_train, y_train)
    y_pred = fitted_model.predict(X_test)

    indices = np.argwhere((X_test == months))[:,0]
    y_test_crop = y_test[indices]
    y_pred_crop = y_pred[indices]
    df_features_test_crop = df_features_test.iloc[indices]
    
    X_lat = df_features_test_crop['lat'].values
    X_lon = df_features_test_crop['lon'].values
    X_alt = df_features_test_crop['altitude'].values
    X_breid = df_features_test_crop['BREID'].values

    y_test_list.extend(y_test_crop)
    y_pred_list.extend(y_pred_crop)
    
    lat_list.extend(X_lat.tolist())
    lon_list.extend(X_lon.tolist())
    alt_list.extend(X_alt.tolist())
    breid_list.extend(X_breid.tolist())

    i=i+1
        
# Arrays of predictions and observations for each fold
lat_all = np.hstack([*lat_list])
lon_all = np.hstack([*lon_list])
alt_all = np.hstack([*alt_list])
breid_all = np.hstack([*breid_list])
y_test_all = np.hstack([*y_test_list])
y_pred_all = np.hstack([*y_pred_list])
residuals_cropped = y_test_all - y_pred_all

# %%
# Plot modelled vs. observed with one color per glacier
import seaborn as sns

all = [596, 675, 1092, 1094, 1144, 2078, 2085, 2297, 2772, 2968, 2474, 2597, 2743, 2148, 2514, 2768, 3133, 3138, 3129, 3137, 3126, 3128]
nn = [596, 675, 1092, 1094, 1144]
alf = [2078, 2085]
jobhar = [2297, 2968, 2474, 2148, 2514]
jot = [2772, 2768, 2597, 2743]
fol = [3133, 3138, 3129, 3137, 3126, 3128]
sel = nn
mask = np.isin(breid_all, sel)

plot_breid = breid_all[mask]
plot_pred = y_pred_all[mask]
plot_test = y_test_all[mask]

# Plot residual vs elevation FOR POSTER

#xy = np.vstack([y_test_all, y_pred_all])
#z = gaussian_kde(xy)(xy)
## Sort the points by density, so that the densest points are plotted last
#idx = z.argsort()
#y_plt, ann_plt, z = y_pred_all[idx], y_test_all[idx], z[idx]

figsize=(6,6)
fontsize=16

fig = plt.figure(figsize=figsize, dpi=200)
#plt.ylim((-12,5))
plt.ylabel('Predicted mb (m w.e)', fontsize=fontsize)
plt.xlabel('Observed mb (m w.e.)', fontsize=fontsize)
sns.scatterplot(x=plot_test, y=plot_pred, hue=plot_breid, legend='full', palette="deep")

#sc = plt.scatter(y_test_all, y_pred_all, s=20, c=breid_all, alpha=0.5)
#plt.clim(0,0.001)
#print(plt.gca().get_ylim())
#plt.colorbar()

#def fit(x,y, sort=True):
#    z = np.polyfit(x, y, 2)
#    fit = np.poly1d(z)
#    if sort:
#        x = np.sort(x)
#    plt.plot(x, fit(x), color="k", alpha=1, lw=3  )  

#fit(y_plt, abs(ann_plt), sort=True) 

#plt.yticks([0,2,4,6])
plt.tick_params(labelsize=fontsize)
plt.axhline(0.0, ls='-.', c='k')
plt.axvline(0.0, ls='-.', c='k')

lineStart = -15
lineEnd = 8
plt.plot([lineStart, lineEnd], [lineStart, lineEnd], 'k-')
plt.xlim(lineStart, lineEnd)
plt.ylim(lineStart, lineEnd)
plt.gca().set_box_aspect(1)
plt.grid(alpha=0.5)
#plt.title(type + ' mass balance')
#plt.savefig('Figures/annual_ae_vs_elevation.png')

# %%
# Plot residual vs elevation FOR POSTER

xy = np.vstack([alt_all, residuals_cropped])
z = gaussian_kde(xy)(xy)
# Sort the points by density, so that the densest points are plotted last
idx = z.argsort()
y_plt, ann_plt, z = alt_all[idx], residuals_cropped[idx], z[idx]

figsize=(5,5)
fontsize=16

fig = plt.figure(figsize=figsize, dpi=300)
plt.ylim((-0.3,7.7))
plt.ylabel('Absolute error (m w.e)', fontsize=fontsize)
plt.xlabel('Elevation (m a.s.l.)', fontsize=fontsize)
sc = plt.scatter(y_plt, abs(ann_plt), c=z, s=20)
plt.clim(0,0.001)
print(plt.gca().get_ylim())

def fit(x,y, sort=True):
    z = np.polyfit(x, y, 2)
    fit = np.poly1d(z)
    if sort:
        x = np.sort(x)
    plt.plot(x, fit(x), color="k", alpha=1, lw=3  )  

fit(y_plt, abs(ann_plt), sort=True) 

plt.yticks([0,2,4,6])
plt.tick_params(labelsize=fontsize)
plt.axhline(0.0, ls='-.', c='k')
plt.gca().set_box_aspect(1)
plt.grid(alpha=0.5)
#plt.title(type + ' mass balance')
#plt.savefig('Figures/annual_ae_vs_elevation.png')
# Out:
# (-0.3, 7.7)

# %%
# Plot residual vs elevation

#xy = np.vstack([lat_all, residuals_cropped])
#z = gaussian_kde(xy)(xy)
# Sort the points by density, so that the densest points are plotted last
#idx = z.argsort()
#y_plt, ann_plt, z = lon_all[idx], residuals_cropped[idx], z[idx]

x = lon_all
y = lat_all
z = residuals_cropped

indices_south = np.argwhere(lat_all<63)
y_s = lat_all[indices_south]
x_s = lon_all[indices_south]
z_s = residuals_cropped[indices_south]

figsize=(8,8)
fontsize=12

fig = plt.figure(figsize=figsize)
plt.ylabel('Absolute error (m.w.e)', fontsize=fontsize)
plt.xlabel('Altitude (m a.s.l.)', fontsize=fontsize)
#sc = plt.scatter(y_plt, ann_plt, c=z, s=20)
sc = plt.scatter(x, y, c=abs(z), s=abs(z)*400, cmap='Reds', vmin=0, vmax=6, edgecolor='k')
#sc = plt.scatter(x, y, s=abs(z)*400, facecolor=None, edgecolor='k')
#plt.clim(0,0.001)

#def fit(x,y, sort=True):
#    z = np.polyfit(x, y, 2)
#    fit = np.poly1d(z)
#    if sort:
#        x = np.sort(x)
#    plt.plot(x, fit(x), color="k", alpha=1, lw=3  )  

#fit(y_plt, abs(ann_plt), sort=True) 
plt.colorbar(sc) 

plt.tick_params(labelsize=14)
#plt.axhline(0.0, ls='-.', c='k')
plt.gca().set_box_aspect(1)
plt.grid(alpha=0.5)
plt.title(type + ' mass balance')

# %% [markdown]
# ### Get predictions as sum of seasonal mass balances

# %%
# Get predictions as sum of seasonal mass balances

y_pred_list_w = []
y_pred_list_s = []
y_pred_list_a = []
y_test_list_w = []
y_test_list_s = []
y_test_list_a = []
idx_list_a = []
idx_list_s = []
idx_list_w = []
i=0

# df_train_a_w_s_all_s is same length as X_train_s and y_train_s, and contains a 
# column 'ann+seas' with bool values: True if both annual and seasonal values exists for this point, False if not. 
# Filter X_train, X_test, y_train and y_test are sorted in the order of altitude in X_

for train_index, test_index in splits_s:
    # Loops over n_splits iterations and gets train and test splits in each fold
    
    X_train, X_test = X_train_s[train_index], X_train_s[test_index]
    y_train, y_test = y_train_s[train_index], y_train_s[test_index]

    # Get feature data for test indices
    df_test = df_train_a_w_s_all_s.iloc[test_index]
    df_test.reset_index(drop=True, inplace=True)
    
    # Get index of rows where 'ann+seas' is True
    idx_ann_seas = df_test.index[df_test['ann+seas']==True]
    df_test_crop = df_test[df_test['ann+seas']==True]
    X_test_ann_seas = X_test[idx_ann_seas]
    y_test_ann_seas = y_test[idx_ann_seas]
    
    fitted_model.fit(X_train, y_train)
    # Predict y using test set where ann+seas = True
    y_pred_ann_seas = fitted_model.predict(X_test_ann_seas)

    # Now have two arrays of all predictions (annual, winter, summer) for points where
    # both annual and seasonal balances are measured. Predictions are not in correct order. 

    # Get predictions and observations of each of seasonal balances and of annual balances.

    # ANNUAL
    indices_a = np.argwhere((X_test_ann_seas == 12))[:,0]
    y_test_crop_annual = y_test_ann_seas[indices_a]
    y_pred_crop_annual = y_pred_ann_seas[indices_a]
    # Get array of ids that will be used to sort lists in ascending order
    sorted_idx_a = df_test_crop.iloc[indices_a].id.values.tolist()

    #y_test_crop_annual_sort = [y_test_crop_annual[i] for i in sorted_idx]
    #y_pred_crop_annual_sort = [y_pred_crop_annual[i] for i in sorted_idx]
    idx_list_a.extend(sorted_idx_a)
    y_test_list_a.extend(y_test_crop_annual)
    y_pred_list_a.extend(y_pred_crop_annual)

    # SUMMER
    indices_s = np.argwhere((X_test_ann_seas == 6))[:,0]
    y_test_crop_summer = y_test_ann_seas[indices_s]
    y_pred_crop_summer = y_pred_ann_seas[indices_s]
    # Get array of ids that will be used to sort lists in ascending order
    sorted_idx_s = df_test_crop.iloc[indices_s].id.values.tolist()

    #y_test_crop_summer_sort = [y_test_crop_summer[i] for i in sorted_idx]
    #y_pred_crop_summer_sort = [y_pred_crop_summer[i] for i in sorted_idx]

    idx_list_s.extend(sorted_idx_s)
    y_test_list_s.extend(y_test_crop_summer)
    y_pred_list_s.extend(y_pred_crop_summer)

    # WINTER
    indices_w = np.argwhere((X_test_ann_seas == 8))[:,0]
    y_test_crop_winter = y_test_ann_seas[indices_w]
    y_pred_crop_winter = y_pred_ann_seas[indices_w]
    # Get array of ids that will be used to sort lists in ascending order
    sorted_idx_w = df_test_crop.iloc[indices_w].id.values.tolist()

    #y_test_crop_winter_sort = [y_test_crop_winter[i] for i in sorted_idx]
    #y_pred_crop_winter_sort = [y_pred_crop_winter[i] for i in sorted_idx]

    idx_list_w.extend(sorted_idx_w)
    y_test_list_w.extend(y_test_crop_winter)
    y_pred_list_w.extend(y_pred_crop_winter)

    #j=i+1
        
# Arrays of predictions and observations for each fold
y_test_all_a = np.hstack([*y_test_list_a])
y_pred_all_a = np.hstack([*y_pred_list_a])
y_test_all_s = np.hstack([*y_test_list_s])
y_pred_all_s = np.hstack([*y_pred_list_s])
y_test_all_w = np.hstack([*y_test_list_w])
y_pred_all_w = np.hstack([*y_pred_list_w])
idx_list_a_all = np.hstack([*idx_list_a])
idx_list_s_all = np.hstack([*idx_list_s])
idx_list_w_all = np.hstack([*idx_list_w])

# %%
# Sort arrays according to identifier

y_pred_all_s_sorted = y_pred_all_s[np.argsort(idx_list_s_all)]
y_test_all_s_sorted = y_test_all_s[np.argsort(idx_list_s_all)]

y_pred_all_w_sorted = y_pred_all_w[np.argsort(idx_list_w_all)]
y_test_all_w_sorted = y_test_all_w[np.argsort(idx_list_w_all)]

y_pred_all_a_sorted = y_pred_all_a[np.argsort(idx_list_a_all)]
y_test_all_a_sorted = y_test_all_a[np.argsort(idx_list_a_all)]

# %%
# Get sum of seasonal mass balances and residuals

y_pred_sum_seas = y_pred_all_s_sorted + y_pred_all_w_sorted

y_test_sum_seas = y_test_all_s_sorted + y_test_all_w_sorted
y_test_sum_seas_sorted = y_test_sum_seas[np.argsort(idx_list_a_all)]

residuals_ann = y_test_all_a_sorted - y_pred_all_a_sorted
residuals_sum_seas = y_test_all_a_sorted - y_pred_sum_seas

print('MAE predict annual: ', round(abs(residuals_ann).mean(),3))
print('MAE predict sum seasonal: ', round(abs(residuals_sum_seas).mean(),3))
# Out:
# MAE predict annual:  1.011
# MAE predict sum seasonal:  0.992

# %%
from sklearn.metrics import r2_score, mean_squared_error

fig = plt.figure(figsize=(8,8))
plt.scatter(y_test_all_a_sorted, y_pred_all_a_sorted, s=7**2, alpha=0.3, label="annual")
#plt.scatter(y_test_all_s_sorted, y_pred_all_s_sorted)
#plt.scatter(y_test_all_w_sorted, y_pred_all_w_sorted)
plt.scatter(y_test_all_a_sorted, y_pred_sum_seas, s=7**2, alpha=0.3, label="sum seasonal")
plt.xlim([-15,8])
plt.ylim([-15,8])
lineStart = -15
lineEnd = 8
plt.plot([lineStart, lineEnd], [lineStart, lineEnd], 'k-')
plt.xlabel('Observed mass balance (m w.e.)', fontsize=12)
plt.ylabel('Predicted mass balance (m w.e.)', fontsize=12)

textstr = '\n'.join((
r'$RMSE_{ann}=%.2f$' % (mean_squared_error(y_test_all_a_sorted, y_pred_all_a_sorted, squared=False), ),
r'$RMSE_{sum seas}=%.2f$' % (mean_squared_error(y_test_all_a_sorted, y_pred_sum_seas, squared=False), ),
r'$MAE_{ann}=%.2f$' % (round(abs(residuals_ann).mean(),3), ),
r'$MAE_{sum seas}=%.2f$' % (round(abs(residuals_sum_seas).mean(),3), ),
r'$R^2_{ann}=%.2f$' % (r2_score(y_test_all_a_sorted, y_pred_all_a_sorted), ),
r'$R^2_{sum seas}=%.2f$' % (r2_score(y_test_all_a_sorted, y_pred_sum_seas), )))
props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
# place a text box in upper left in axes coords
plt.text(0.05, 0.95, textstr, transform=plt.gca().transAxes, fontsize=14,
        verticalalignment='top', bbox=props)

plt.legend(loc='lower right')
plt.grid()
plt.show()

# %%
# Residuals vs. predicted mass balance as scatter plot

fontsize_labels=12

fig1, ax = plt.subplots(1,1, figsize=(8,8))
ax.scatter(y_test_all_a_sorted, abs(residuals_ann), color='C0', alpha=0.2, label='annual')
ax.scatter(y_test_all_a_sorted, abs(residuals_sum_seas), color='C1', alpha=0.2, label='sum seasonal')

def fit(ax, x,y, color, sort=True):
    z = np.polyfit(x, y, 4)
    fit = np.poly1d(z)
    if sort:
        x = np.sort(x)
    ax.plot(x, fit(x), color=color, alpha=1, lw=3  )  
    #ax.legend()

fit(ax, y_test_all_a_sorted, abs(residuals_ann), color='C0', sort=True) 
fit(ax, y_test_all_a_sorted, abs(residuals_sum_seas), color='C1', sort=True) 

ax.set_xlabel('Observed ' + type + ' point mass balance (m w.e.)', fontsize=fontsize_labels)
ax.set_ylabel('Absolute error (m w.e.)', fontsize=fontsize_labels)
ax.legend()
ax.grid(visible=True, which='both')

# %%
# Residuals vs. predicted mass balance as scatter plot

fontsize_labels=12

fig1, ax = plt.subplots(1,1, figsize=(8,8))
ax.scatter(y_test_all_a_sorted, (abs(residuals_ann)-abs(residuals_sum_seas)), color='k', alpha=0.2)
#ax.scatter(y_test_all_a_sorted, abs(residuals_sum_seas), color='C1', alpha=0.2)

def fit(ax, x,y, color, sort=True):
    z = np.polyfit(x, y, 6)
    fit = np.poly1d(z)
    if sort:
        #x_idx = np.argsort(x)
        x = np.sort(x)
        #y = y[x_idx]
    ax.plot(x, fit(x), color=color, alpha=1, lw=3  ) 
    #ax.plot(x,y)
    #ax.legend()

fit(ax, y_test_all_a_sorted, (abs(residuals_ann)-abs(residuals_sum_seas)), color='C0', sort=True) 
#fit(ax, y_test_all_a_sorted, abs(residuals_sum_seas), color='C1', sort=True) 

ax.set_xlabel('Observed ' + type + ' point mass balance (m w.e.)', fontsize=fontsize_labels)
ax.set_ylabel('Error$_{ann}$ - error$_{sum seas}$ (m w.e.)', fontsize=fontsize_labels)
ax.axvline(ymin=-3, ymax=2, linestyle='-.', color='r')
ax.grid(visible=True, which='both')

# %%
percent_error_seas = abs(np.divide(residuals_sum_seas,y_pred_sum_seas))*100
percent_error_ann = abs(np.divide(residuals_ann,y_pred_all_a_sorted))*100
indices_perc_seas = np.argwhere((percent_error_seas < 1000))
indices_perc_ann = np.argwhere((percent_error_ann < 1000))

percent_error_seas_crop = percent_error_seas[indices_perc_seas]
percent_error_ann_crop = percent_error_ann[indices_perc_ann]

y_pred_sum_seas_perc = y_pred_sum_seas[indices_perc_seas]
y_pred_ann_perc = y_pred_all_a_sorted[indices_perc_ann]

# %%
# Residuals vs. predicted mass balance as scatter plot
fontsize_labels=12

fig1, ax = plt.subplots(1,1, figsize=(8,8))
ax.scatter(y_pred_sum_seas_perc, percent_error_seas_crop, color='k', alpha=0.2)
#ax.scatter(y_pred_ann_perc, percent_error_ann_crop, color='C1', alpha=0.2)
#ax.scatter(y_test_all_a_sorted, abs(residuals_sum_seas), color='C1', alpha=0.2)

def fit(ax, x,y, color, sort=True):
    z = np.polyfit(x, y, 6)
    fit = np.poly1d(z)
    if sort:
        #x_idx = np.argsort(x)
        x = np.sort(x)
        #y = y[x_idx]
    ax.plot(x, fit(x), color=color, alpha=1, lw=3  ) 
    #ax.plot(x,y)
    #ax.legend()

#fit(ax, y_test_all_a_sorted, (abs(residuals_ann)-abs(residuals_sum_seas)), color='C0', sort=True) 
#fit(ax, y_test_all_a_sorted, abs(residuals_sum_seas), color='C1', sort=True) 

ax.set_xlabel('Predicted ' + type + ' point mass balance (m w.e.)', fontsize=fontsize_labels)
ax.set_ylabel('Percentage error', fontsize=fontsize_labels)
ax.axhline(50, xmin=-12, xmax=5, linestyle='-.', color='r')
ax.axvline(-5, ymin=0, ymax=1100, linestyle='-.', color='r')
ax.grid(visible=True, which='both')
